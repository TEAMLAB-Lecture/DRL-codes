# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import csv
import os

class Grid:
    def __init__(self, size=5, start_pos=(0, 0), exit_pos=(4, 4)):
        self.size = size
        self.exit_pos = exit_pos
        self.figure_pos = start_pos

    def move(self, direction):
        x, y = self.figure_pos
        if direction == 0 and y > 0:  # up
            self.figure_pos = (x, y-1)
        elif direction == 1 and y < self.size-1:  # down
            self.figure_pos = (x, y+1)
        elif direction == 2 and x > 0:  # left
            self.figure_pos = (x-1, y)
        elif direction == 3 and x < self.size-1:  # right
            self.figure_pos = (x+1, y)

    def is_at_exit(self):
        return self.figure_pos == self.exit_pos

    def get_state(self, device='cpu'):
        return torch.FloatTensor(self.figure_pos).unsqueeze(0).to(device)

class PolicyNet(nn.Module):
    def __init__(self):
        super(PolicyNet, self).__init__()
        self.fc1 = nn.Linear(2, 16)
        self.fc2 = nn.Linear(16, 4)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        x = F.softmax(x, dim=1)
        return x

def generate_episode(grid, policy_net, device="cpu", max_episode_len=100):
    episode = []
    state = grid.get_state(device)
    ep_length = 0

    while not grid.is_at_exit() and ep_length < max_episode_len:
        ep_length += 1
        action_probs = policy_net(state).squeeze()
        log_probs = torch.log(action_probs)
        cpu_action_probs = action_probs.detach().cpu().numpy()
        action = np.random.choice(np.arange(4), p=cpu_action_probs)

        grid.move(action)
        next_state = grid.get_state(device)
        reward = -0.1 if not grid.is_at_exit() else 1.0  # 도착하면 +1 보상

        # 각 행동에 대한 로그 확률을 저장
        episode.append((state.tolist(), action, reward, log_probs.tolist()))

        if reward == 1.0:  # 목표에 도달했을 때 에피소드 종료
            break

        state = next_state

    return episode

def compute_discounted_rewards(rewards, gamma=0.99):
    discounted_rewards = []
    R = 0
    for reward in reversed(rewards):
        R = reward + gamma * R
        discounted_rewards.insert(0, R)
    return discounted_rewards

# 환경과 네트워크 초기화
grid = Grid(size=5, start_pos=(0, 0), exit_pos=(4, 4))
policy_net = PolicyNet()


model_path = 'policy_net.pth'

if os.path.exists(model_path):
    # 모델이 이미 존재하면 로드
    policy_net.load_state_dict(torch.load(model_path))
    print("학습된 모델을 로드했습니다.")

# 에피소드 생성
episode = generate_episode(grid, policy_net)

# 에피소드에서 보상만 추출
rewards = [step[2] for step in episode]

# 할인된 누적 보상 계산
discounted_rewards = compute_discounted_rewards(rewards)

# 생성된 에피소드 데이터를 파일에 저장 (할인된 보상 추가)
with open('episode_data_with_discounted_rewards.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['State', 'Action', 'Reward', 'Log Probs', 'Discounted Reward'])
    for i, step in enumerate(episode):
        state, action, reward, log_probs = step
        writer.writerow([state, action, reward, log_probs, discounted_rewards[i]])

# 저장된 데이터를 확인
print("Episode data with discounted rewards saved to 'episode_data_with_discounted_rewards.csv'")
# Out:
# Episode data with discounted rewards saved to 'episode_data_with_discounted_rewards.csv'

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import csv

def load_episode_data(file_path):
    states = []
    actions = []
    rewards = []
    log_probs = []
    discounted_rewards = []

    with open(file_path, mode='r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            state = [float(i) for i in row['State'].strip('][').split(', ')]
            action = int(row['Action'])
            reward = float(row['Reward'])
            log_prob = [float(i) for i in row['Log Probs'].strip('][').split(', ')]
            discounted_reward = float(row['Discounted Reward'])

            states.append(state)
            actions.append(action)
            rewards.append(reward)
            log_probs.append(log_prob)
            discounted_rewards.append(discounted_reward)

    return states, actions, rewards, log_probs, discounted_rewards

def train_policy_net(policy_net, optimizer, states, actions, log_probs, discounted_rewards, device='cpu'):
    policy_net.train()
    optimizer.zero_grad()

    states = torch.tensor(states, dtype=torch.float32).to(device)
    actions = torch.tensor(actions, dtype=torch.int64).to(device)
    discounted_rewards = torch.tensor(discounted_rewards, dtype=torch.float32).to(device)

    action_probs = policy_net(states)
    log_action_probs = torch.log(action_probs)

    selected_log_probs = log_action_probs.gather(1, actions.unsqueeze(1)).squeeze()
    loss = -selected_log_probs * discounted_rewards
    loss = loss.mean()

    loss.backward()
    optimizer.step()

# 환경과 네트워크 초기화
grid = Grid(size=5, start_pos=(0, 0), exit_pos=(4, 4))
policy_net = PolicyNet()

model_path = 'policy_net.pth'

if os.path.exists(model_path):
    # 모델이 이미 존재하면 로드
    policy_net.load_state_dict(torch.load(model_path))
    print("학습된 모델을 로드했습니다.")


optimizer = optim.Adam(policy_net.parameters(), lr=0.01)

# 에피소드 데이터 로드
file_path = 'episode_data_with_discounted_rewards.csv'
states, actions, rewards, log_probs, discounted_rewards = load_episode_data(file_path)

# PolicyNet 학습
train_policy_net(policy_net, optimizer, states, actions, log_probs, discounted_rewards)

# 학습된 모델 저장
torch.save(policy_net.state_dict(), 'policy_net.pth')

print("PolicyNet 학습 및 저장 완료")
# Out:
# PolicyNet 학습 및 저장 완료

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
import imageio



def visualize_episode(grid, policy_net, device='cpu', max_episode_len=100):
    frames = []  # Store each frame here to make a video
    episode_info = []  # To store episode information

    policy_net.eval()
    with torch.no_grad():
        for step in range(max_episode_len):
            plt.figure(figsize=(5, 5))
            plt.xticks([])
            plt.yticks([])
            plt.imshow(np.zeros((grid.size, grid.size)), cmap='gray', vmin=0, vmax=1)
            plt.text(grid.exit_pos[0], grid.exit_pos[1], 'Exit', ha='center', va='center', color='green', fontsize=12)
            plt.text(grid.figure_pos[0], grid.figure_pos[1], 'Agent', ha='center', va='center', color='blue', fontsize=12)
            plt.grid(True)
            plt.title(f"Step: {step + 1}")
            plt.savefig('frame.png')
            plt.close()
            frames.append(imageio.imread('frame.png'))

            state = grid.get_state(device)
            action_probs = policy_net(state).squeeze()
            action = np.random.choice(np.arange(4), p=action_probs.detach().cpu().numpy())
            episode_info.append((state.cpu().numpy().tolist(), action))  # Store state and action

            grid.move(action)
            if grid.is_at_exit():
                break

    # Output episode information
    for info in episode_info:
        print(f"State: {info[0]}, Action: {action_probs}")

    # Save the visualized episode
    imageio.mimsave('game_progress.gif', frames, fps=1)
    imageio.mimsave('game_progress.mp4', frames, fps=1)

# 학습된 정책 네트워크 로드
# 정책 네트워크를 학습하고 저장한 후, 여기서 로드해야 합니다.
policy_net = PolicyNet()
policy_net.load_state_dict(torch.load('policy_net.pth'))  # 학습된 모델 파일 로드

# 환경 초기화 및 에피소드 시각화
grid = Grid(size=5, start_pos=(0, 0), exit_pos=(4, 4))
visualize_episode(grid, policy_net)
# Out:
# <ipython-input-3-cea54f1510a8>:27: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   frames.append(imageio.imread('frame.png'))
# State: [[0.0, 0.0]], Action: tensor([0.1160, 0.2961, 0.0172, 0.5708])
# State: [[1.0, 0.0]], Action: tensor([0.1160, 0.2961, 0.0172, 0.5708])
# State: [[2.0, 0.0]], Action: tensor([0.1160, 0.2961, 0.0172, 0.5708])
# State: [[3.0, 0.0]], Action: tensor([0.1160, 0.2961, 0.0172, 0.5708])
# State: [[4.0, 0.0]], Action: tensor([0.1160, 0.2961, 0.0172, 0.5708])
# State: [[4.0, 0.0]], Action: tensor([0.1160, 0.2961, 0.0172, 0.5708])
# State: [[4.0, 1.0]], Action: tensor([0.1160, 0.2961, 0.0172, 0.5708])
# State: [[4.0, 1.0]], Action: tensor([0.1160, 0.2961, 0.0172, 0.5708])
# State: [[4.0, 1.0]], Action: tensor([0.1160, 0.2961, 0.0172, 0.5708])
# State: [[4.0, 2.0]], Action: tensor([0.1160, 0.2961, 0.0172, 0.5708])
# State: [[4.0, 3.0]], Action: tensor([0.1160, 0.2961, 0.0172, 0.5708])
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import csv
import os

class Grid:
    def __init__(self, size=5, start_pos=(0, 0), exit_pos=(4, 4)):
        self.size = size
        self.exit_pos = exit_pos
        self.start_pos = start_pos
        self.figure_pos = start_pos

    def reset(self):
        self.figure_pos = self.start_pos

    def move(self, direction):
        x, y = self.figure_pos
        if direction == 0 and y > 0:  # up
            self.figure_pos = (x, y-1)
        elif direction == 1 and y < self.size-1:  # down
            self.figure_pos = (x, y+1)
        elif direction == 2 and x > 0:  # left
            self.figure_pos = (x-1, y)
        elif direction == 3 and x < self.size-1:  # right
            self.figure_pos = (x+1, y)

    def is_at_exit(self):
        return self.figure_pos == self.exit_pos

    def get_state(self, device='cpu'):
        return torch.FloatTensor(self.figure_pos).unsqueeze(0).to(device)

class PolicyNet(nn.Module):
    def __init__(self):
        super(PolicyNet, self).__init__()
        self.fc1 = nn.Linear(2, 16)
        self.fc2 = nn.Linear(16, 4)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        x = F.softmax(x, dim=1)
        return x

def generate_episode(grid, policy_net, device="cpu", max_episode_len=100):
    episode = []
    state = grid.get_state(device)
    ep_length = 0

    while not grid.is_at_exit() and ep_length < max_episode_len:
        ep_length += 1
        action_probs = policy_net(state).squeeze()
        log_probs = torch.log(action_probs)
        cpu_action_probs = action_probs.detach().cpu().numpy()
        action = np.random.choice(np.arange(4), p=cpu_action_probs)

        grid.move(action)
        next_state = grid.get_state(device)
        reward = -0.1 if not grid.is_at_exit() else 1.0  # 도착하면 +1 보상

        # 각 행동에 대한 로그 확률을 저장
        episode.append((state.tolist(), action, reward, log_probs.tolist()))

        if reward == 1.0:  # 목표에 도달했을 때 에피소드 종료
            break

        state = next_state

    return episode

def compute_discounted_rewards(rewards, gamma=0.99):
    discounted_rewards = []
    R = 0
    for reward in reversed(rewards):
        R = reward + gamma * R
        discounted_rewards.insert(0, R)
    return discounted_rewards

def load_episode_data(file_path):
    states = []
    actions = []
    rewards = []
    log_probs = []
    discounted_rewards = []

    with open(file_path, mode='r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            state = [float(i) for i in row['State'].strip('][').split(', ')]
            action = int(row['Action'])
            reward = float(row['Reward'])
            log_prob = [float(i) for i in row['Log Probs'].strip('][').split(', ')]
            discounted_reward = float(row['Discounted Reward'])

            states.append(state)
            actions.append(action)
            rewards.append(reward)
            log_probs.append(log_prob)
            discounted_rewards.append(discounted_reward)

    return states, actions, rewards, log_probs, discounted_rewards

def train_policy_net(policy_net, optimizer, states, actions, log_probs, discounted_rewards, device='cpu'):
    policy_net.train()
    optimizer.zero_grad()

    states = torch.tensor(states, dtype=torch.float32).to(device)
    actions = torch.tensor(actions, dtype=torch.int64).to(device)
    discounted_rewards = torch.tensor(discounted_rewards, dtype=torch.float32).to(device)

    action_probs = policy_net(states)
    log_action_probs = torch.log(action_probs)

    selected_log_probs = log_action_probs.gather(1, actions.unsqueeze(1)).squeeze()
    loss = -selected_log_probs * discounted_rewards
    loss = loss.mean()

    loss.backward()
    optimizer.step()

def main(num_iterations=100):
    # 환경과 네트워크 초기화
    grid = Grid(size=10, start_pos=(0, 0), exit_pos=(6, 5))
    policy_net = PolicyNet()
    optimizer = optim.Adam(policy_net.parameters(), lr=0.01)
    file_path = 'episode_data_with_discounted_rewards.csv'
    model_path = 'policy_net.pth'

    if os.path.exists(model_path):
        # 모델이 이미 존재하면 로드
        policy_net.load_state_dict(torch.load(model_path))
        print("학습된 모델을 로드했습니다.")

    for i in range(num_iterations):
        print(f"Iteration {i+1}/{num_iterations}")

        # 그리드 초기화
        grid.reset()

        # 에피소드 생성
        episode = generate_episode(grid, policy_net)

        # 에피소드에서 보상만 추출
        rewards = [step[2] for step in episode]

        # 할인된 누적 보상 계산
        discounted_rewards = compute_discounted_rewards(rewards)

        # 생성된 에피소드 데이터를 파일에 저장 (할인된 보상 추가)
        with open(file_path, mode='w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(['State', 'Action', 'Reward', 'Log Probs', 'Discounted Reward'])
            for i, step in enumerate(episode):
                state, action, reward, log_probs = step
                writer.writerow([state, action, reward, log_probs, discounted_rewards[i]])

        # 에피소드 데이터 로드
        states, actions, rewards, log_probs, discounted_rewards = load_episode_data(file_path)

        # PolicyNet 학습
        train_policy_net(policy_net, optimizer, states, actions, log_probs, discounted_rewards)

        # 학습된 모델 저장
        torch.save(policy_net.state_dict(), model_path)

        print("PolicyNet 학습 및 저장 완료")

if __name__ == "__main__":
    main(num_iterations=500)  # 원하는 반복 횟수 설정
# Out:
# Iteration 1/500
# PolicyNet 학습 및 저장 완료
# Iteration 2/500
# PolicyNet 학습 및 저장 완료
# Iteration 3/500
# PolicyNet 학습 및 저장 완료
# Iteration 4/500
# PolicyNet 학습 및 저장 완료
# Iteration 5/500
# PolicyNet 학습 및 저장 완료
# Iteration 6/500
# PolicyNet 학습 및 저장 완료
# Iteration 7/500
# PolicyNet 학습 및 저장 완료
# Iteration 8/500
# PolicyNet 학습 및 저장 완료
# Iteration 9/500
# PolicyNet 학습 및 저장 완료
# Iteration 10/500
# PolicyNet 학습 및 저장 완료
# Iteration 11/500
# PolicyNet 학습 및 저장 완료
# Iteration 12/500
# PolicyNet 학습 및 저장 완료
# Iteration 13/500
# PolicyNet 학습 및 저장 완료
# Iteration 14/500
# PolicyNet 학습 및 저장 완료
# Iteration 15/500
# PolicyNet 학습 및 저장 완료
# Iteration 16/500
# PolicyNet 학습 및 저장 완료
# Iteration 17/500
# PolicyNet 학습 및 저장 완료
# Iteration 18/500
# PolicyNet 학습 및 저장 완료
# Iteration 19/500
# PolicyNet 학습 및 저장 완료
# Iteration 20/500
# PolicyNet 학습 및 저장 완료
# Iteration 21/500
# PolicyNet 학습 및 저장 완료
# Iteration 22/500
# PolicyNet 학습 및 저장 완료
# Iteration 23/500
# PolicyNet 학습 및 저장 완료
# Iteration 24/500
# PolicyNet 학습 및 저장 완료
# Iteration 25/500
# PolicyNet 학습 및 저장 완료
# Iteration 26/500
# PolicyNet 학습 및 저장 완료
# Iteration 27/500
# PolicyNet 학습 및 저장 완료
# Iteration 28/500
# PolicyNet 학습 및 저장 완료
# Iteration 29/500
# PolicyNet 학습 및 저장 완료
# Iteration 30/500
# PolicyNet 학습 및 저장 완료
# Iteration 31/500
# PolicyNet 학습 및 저장 완료
# Iteration 32/500
# PolicyNet 학습 및 저장 완료
# Iteration 33/500
# PolicyNet 학습 및 저장 완료
# Iteration 34/500
# PolicyNet 학습 및 저장 완료
# Iteration 35/500
# PolicyNet 학습 및 저장 완료
# Iteration 36/500
# PolicyNet 학습 및 저장 완료
# Iteration 37/500
# PolicyNet 학습 및 저장 완료
# Iteration 38/500
# PolicyNet 학습 및 저장 완료
# Iteration 39/500
# PolicyNet 학습 및 저장 완료
# Iteration 40/500
# PolicyNet 학습 및 저장 완료
# Iteration 41/500
# PolicyNet 학습 및 저장 완료
# Iteration 42/500
# PolicyNet 학습 및 저장 완료
# Iteration 43/500
# PolicyNet 학습 및 저장 완료
# Iteration 44/500
# PolicyNet 학습 및 저장 완료
# Iteration 45/500
# PolicyNet 학습 및 저장 완료
# Iteration 46/500
# PolicyNet 학습 및 저장 완료
# Iteration 47/500
# PolicyNet 학습 및 저장 완료
# Iteration 48/500
# PolicyNet 학습 및 저장 완료
# Iteration 49/500
# PolicyNet 학습 및 저장 완료
# Iteration 50/500
# PolicyNet 학습 및 저장 완료
# Iteration 51/500
# PolicyNet 학습 및 저장 완료
# Iteration 52/500
# PolicyNet 학습 및 저장 완료
# Iteration 53/500
# PolicyNet 학습 및 저장 완료
# Iteration 54/500
# PolicyNet 학습 및 저장 완료
# Iteration 55/500
# PolicyNet 학습 및 저장 완료
# Iteration 56/500
# PolicyNet 학습 및 저장 완료
# Iteration 57/500
# PolicyNet 학습 및 저장 완료
# Iteration 58/500
# PolicyNet 학습 및 저장 완료
# Iteration 59/500
# PolicyNet 학습 및 저장 완료
# Iteration 60/500
# PolicyNet 학습 및 저장 완료
# Iteration 61/500
# PolicyNet 학습 및 저장 완료
# Iteration 62/500
# PolicyNet 학습 및 저장 완료
# Iteration 63/500
# PolicyNet 학습 및 저장 완료
# Iteration 64/500
# PolicyNet 학습 및 저장 완료
# Iteration 65/500
# PolicyNet 학습 및 저장 완료
# Iteration 66/500
# PolicyNet 학습 및 저장 완료
# Iteration 67/500
# PolicyNet 학습 및 저장 완료
# Iteration 68/500
# PolicyNet 학습 및 저장 완료
# Iteration 69/500
# PolicyNet 학습 및 저장 완료
# Iteration 70/500
# PolicyNet 학습 및 저장 완료
# Iteration 71/500
# PolicyNet 학습 및 저장 완료
# Iteration 72/500
# PolicyNet 학습 및 저장 완료
# Iteration 73/500
# PolicyNet 학습 및 저장 완료
# Iteration 74/500
# PolicyNet 학습 및 저장 완료
# Iteration 75/500
# PolicyNet 학습 및 저장 완료
# Iteration 76/500
# PolicyNet 학습 및 저장 완료
# Iteration 77/500
# PolicyNet 학습 및 저장 완료
# Iteration 78/500
# PolicyNet 학습 및 저장 완료
# Iteration 79/500
# PolicyNet 학습 및 저장 완료
# Iteration 80/500
# PolicyNet 학습 및 저장 완료
# Iteration 81/500
# PolicyNet 학습 및 저장 완료
# Iteration 82/500
# PolicyNet 학습 및 저장 완료
# Iteration 83/500
# PolicyNet 학습 및 저장 완료
# Iteration 84/500
# PolicyNet 학습 및 저장 완료
# Iteration 85/500
# PolicyNet 학습 및 저장 완료
# Iteration 86/500
# PolicyNet 학습 및 저장 완료
# Iteration 87/500
# PolicyNet 학습 및 저장 완료
# Iteration 88/500
# PolicyNet 학습 및 저장 완료
# Iteration 89/500
# PolicyNet 학습 및 저장 완료
# Iteration 90/500
# PolicyNet 학습 및 저장 완료
# Iteration 91/500
# PolicyNet 학습 및 저장 완료
# Iteration 92/500
# PolicyNet 학습 및 저장 완료
# Iteration 93/500
# PolicyNet 학습 및 저장 완료
# Iteration 94/500
# PolicyNet 학습 및 저장 완료
# Iteration 95/500
# PolicyNet 학습 및 저장 완료
# Iteration 96/500
# PolicyNet 학습 및 저장 완료
# Iteration 97/500
# PolicyNet 학습 및 저장 완료
# Iteration 98/500
# PolicyNet 학습 및 저장 완료
# Iteration 99/500
# PolicyNet 학습 및 저장 완료
# Iteration 100/500
# PolicyNet 학습 및 저장 완료
# Iteration 101/500
# PolicyNet 학습 및 저장 완료
# Iteration 102/500
# PolicyNet 학습 및 저장 완료
# Iteration 103/500
# PolicyNet 학습 및 저장 완료
# Iteration 104/500
# PolicyNet 학습 및 저장 완료
# Iteration 105/500
# PolicyNet 학습 및 저장 완료
# Iteration 106/500
# PolicyNet 학습 및 저장 완료
# Iteration 107/500
# PolicyNet 학습 및 저장 완료
# Iteration 108/500
# PolicyNet 학습 및 저장 완료
# Iteration 109/500
# PolicyNet 학습 및 저장 완료
# Iteration 110/500
# PolicyNet 학습 및 저장 완료
# Iteration 111/500
# PolicyNet 학습 및 저장 완료
# Iteration 112/500
# PolicyNet 학습 및 저장 완료
# Iteration 113/500
# PolicyNet 학습 및 저장 완료
# Iteration 114/500
# PolicyNet 학습 및 저장 완료
# Iteration 115/500
# PolicyNet 학습 및 저장 완료
# Iteration 116/500
# PolicyNet 학습 및 저장 완료
# Iteration 117/500
# PolicyNet 학습 및 저장 완료
# Iteration 118/500
# PolicyNet 학습 및 저장 완료
# Iteration 119/500
# PolicyNet 학습 및 저장 완료
# Iteration 120/500
# PolicyNet 학습 및 저장 완료
# Iteration 121/500
# PolicyNet 학습 및 저장 완료
# Iteration 122/500
# PolicyNet 학습 및 저장 완료
# Iteration 123/500
# PolicyNet 학습 및 저장 완료
# Iteration 124/500
# PolicyNet 학습 및 저장 완료
# Iteration 125/500
# PolicyNet 학습 및 저장 완료
# Iteration 126/500
# PolicyNet 학습 및 저장 완료
# Iteration 127/500
# PolicyNet 학습 및 저장 완료
# Iteration 128/500
# PolicyNet 학습 및 저장 완료
# Iteration 129/500
# PolicyNet 학습 및 저장 완료
# Iteration 130/500
# PolicyNet 학습 및 저장 완료
# Iteration 131/500
# PolicyNet 학습 및 저장 완료
# Iteration 132/500
# PolicyNet 학습 및 저장 완료
# Iteration 133/500
# PolicyNet 학습 및 저장 완료
# Iteration 134/500
# PolicyNet 학습 및 저장 완료
# Iteration 135/500
# PolicyNet 학습 및 저장 완료
# Iteration 136/500
# PolicyNet 학습 및 저장 완료
# Iteration 137/500
# PolicyNet 학습 및 저장 완료
# Iteration 138/500
# PolicyNet 학습 및 저장 완료
# Iteration 139/500
# PolicyNet 학습 및 저장 완료
# Iteration 140/500
# PolicyNet 학습 및 저장 완료
# Iteration 141/500
# PolicyNet 학습 및 저장 완료
# Iteration 142/500
# PolicyNet 학습 및 저장 완료
# Iteration 143/500
# PolicyNet 학습 및 저장 완료
# Iteration 144/500
# PolicyNet 학습 및 저장 완료
# Iteration 145/500
# PolicyNet 학습 및 저장 완료
# Iteration 146/500
# PolicyNet 학습 및 저장 완료
# Iteration 147/500
# PolicyNet 학습 및 저장 완료
# Iteration 148/500
# PolicyNet 학습 및 저장 완료
# Iteration 149/500
# PolicyNet 학습 및 저장 완료
# Iteration 150/500
# PolicyNet 학습 및 저장 완료
# Iteration 151/500
# PolicyNet 학습 및 저장 완료
# Iteration 152/500
# PolicyNet 학습 및 저장 완료
# Iteration 153/500
# PolicyNet 학습 및 저장 완료
# Iteration 154/500
# PolicyNet 학습 및 저장 완료
# Iteration 155/500
# PolicyNet 학습 및 저장 완료
# Iteration 156/500
# PolicyNet 학습 및 저장 완료
# Iteration 157/500
# PolicyNet 학습 및 저장 완료
# Iteration 158/500
# PolicyNet 학습 및 저장 완료
# Iteration 159/500
# PolicyNet 학습 및 저장 완료
# Iteration 160/500
# PolicyNet 학습 및 저장 완료
# Iteration 161/500
# PolicyNet 학습 및 저장 완료
# Iteration 162/500
# PolicyNet 학습 및 저장 완료
# Iteration 163/500
# PolicyNet 학습 및 저장 완료
# Iteration 164/500
# PolicyNet 학습 및 저장 완료
# Iteration 165/500
# PolicyNet 학습 및 저장 완료
# Iteration 166/500
# PolicyNet 학습 및 저장 완료
# Iteration 167/500
# PolicyNet 학습 및 저장 완료
# Iteration 168/500
# PolicyNet 학습 및 저장 완료
# Iteration 169/500
# PolicyNet 학습 및 저장 완료
# Iteration 170/500
# PolicyNet 학습 및 저장 완료
# Iteration 171/500
# PolicyNet 학습 및 저장 완료
# Iteration 172/500
# PolicyNet 학습 및 저장 완료
# Iteration 173/500
# PolicyNet 학습 및 저장 완료
# Iteration 174/500
# PolicyNet 학습 및 저장 완료
# Iteration 175/500
# PolicyNet 학습 및 저장 완료
# Iteration 176/500
# PolicyNet 학습 및 저장 완료
# Iteration 177/500
# PolicyNet 학습 및 저장 완료
# Iteration 178/500
# PolicyNet 학습 및 저장 완료
# Iteration 179/500
# PolicyNet 학습 및 저장 완료
# Iteration 180/500
# PolicyNet 학습 및 저장 완료
# Iteration 181/500
# PolicyNet 학습 및 저장 완료
# Iteration 182/500
# PolicyNet 학습 및 저장 완료
# Iteration 183/500
# PolicyNet 학습 및 저장 완료
# Iteration 184/500
# PolicyNet 학습 및 저장 완료
# Iteration 185/500
# PolicyNet 학습 및 저장 완료
# Iteration 186/500
# PolicyNet 학습 및 저장 완료
# Iteration 187/500
# PolicyNet 학습 및 저장 완료
# Iteration 188/500
# PolicyNet 학습 및 저장 완료
# Iteration 189/500
# PolicyNet 학습 및 저장 완료
# Iteration 190/500
# PolicyNet 학습 및 저장 완료
# Iteration 191/500
# PolicyNet 학습 및 저장 완료
# Iteration 192/500
# PolicyNet 학습 및 저장 완료
# Iteration 193/500
# PolicyNet 학습 및 저장 완료
# Iteration 194/500
# PolicyNet 학습 및 저장 완료
# Iteration 195/500
# PolicyNet 학습 및 저장 완료
# Iteration 196/500
# PolicyNet 학습 및 저장 완료
# Iteration 197/500
# PolicyNet 학습 및 저장 완료
# Iteration 198/500
# PolicyNet 학습 및 저장 완료
# Iteration 199/500
# PolicyNet 학습 및 저장 완료
# Iteration 200/500
# PolicyNet 학습 및 저장 완료
# Iteration 201/500
# PolicyNet 학습 및 저장 완료
# Iteration 202/500
# PolicyNet 학습 및 저장 완료
# Iteration 203/500
# PolicyNet 학습 및 저장 완료
# Iteration 204/500
# PolicyNet 학습 및 저장 완료
# Iteration 205/500
# PolicyNet 학습 및 저장 완료
# Iteration 206/500
# PolicyNet 학습 및 저장 완료
# Iteration 207/500
# PolicyNet 학습 및 저장 완료
# Iteration 208/500
# PolicyNet 학습 및 저장 완료
# Iteration 209/500
# PolicyNet 학습 및 저장 완료
# Iteration 210/500
# PolicyNet 학습 및 저장 완료
# Iteration 211/500
# PolicyNet 학습 및 저장 완료
# Iteration 212/500
# PolicyNet 학습 및 저장 완료
# Iteration 213/500
# PolicyNet 학습 및 저장 완료
# Iteration 214/500
# PolicyNet 학습 및 저장 완료
# Iteration 215/500
# PolicyNet 학습 및 저장 완료
# Iteration 216/500
# PolicyNet 학습 및 저장 완료
# Iteration 217/500
# PolicyNet 학습 및 저장 완료
# Iteration 218/500
# PolicyNet 학습 및 저장 완료
# Iteration 219/500
# PolicyNet 학습 및 저장 완료
# Iteration 220/500
# PolicyNet 학습 및 저장 완료
# Iteration 221/500
# PolicyNet 학습 및 저장 완료
# Iteration 222/500
# PolicyNet 학습 및 저장 완료
# Iteration 223/500
# PolicyNet 학습 및 저장 완료
# Iteration 224/500
# PolicyNet 학습 및 저장 완료
# Iteration 225/500
# PolicyNet 학습 및 저장 완료
# Iteration 226/500
# PolicyNet 학습 및 저장 완료
# Iteration 227/500
# PolicyNet 학습 및 저장 완료
# Iteration 228/500
# PolicyNet 학습 및 저장 완료
# Iteration 229/500
# PolicyNet 학습 및 저장 완료
# Iteration 230/500
# PolicyNet 학습 및 저장 완료
# Iteration 231/500
# PolicyNet 학습 및 저장 완료
# Iteration 232/500
# PolicyNet 학습 및 저장 완료
# Iteration 233/500
# PolicyNet 학습 및 저장 완료
# Iteration 234/500
# PolicyNet 학습 및 저장 완료
# Iteration 235/500
# PolicyNet 학습 및 저장 완료
# Iteration 236/500
# PolicyNet 학습 및 저장 완료
# Iteration 237/500
# PolicyNet 학습 및 저장 완료
# Iteration 238/500
# PolicyNet 학습 및 저장 완료
# Iteration 239/500
# PolicyNet 학습 및 저장 완료
# Iteration 240/500
# PolicyNet 학습 및 저장 완료
# Iteration 241/500
# PolicyNet 학습 및 저장 완료
# Iteration 242/500
# PolicyNet 학습 및 저장 완료
# Iteration 243/500
# PolicyNet 학습 및 저장 완료
# Iteration 244/500
# PolicyNet 학습 및 저장 완료
# Iteration 245/500
# PolicyNet 학습 및 저장 완료
# Iteration 246/500
# PolicyNet 학습 및 저장 완료
# Iteration 247/500
# PolicyNet 학습 및 저장 완료
# Iteration 248/500
# PolicyNet 학습 및 저장 완료
# Iteration 249/500
# PolicyNet 학습 및 저장 완료
# Iteration 250/500
# PolicyNet 학습 및 저장 완료
# Iteration 251/500
# PolicyNet 학습 및 저장 완료
# Iteration 252/500
# PolicyNet 학습 및 저장 완료
# Iteration 253/500
# PolicyNet 학습 및 저장 완료
# Iteration 254/500
# PolicyNet 학습 및 저장 완료
# Iteration 255/500
# PolicyNet 학습 및 저장 완료
# Iteration 256/500
# PolicyNet 학습 및 저장 완료
# Iteration 257/500
# PolicyNet 학습 및 저장 완료
# Iteration 258/500
# PolicyNet 학습 및 저장 완료
# Iteration 259/500
# PolicyNet 학습 및 저장 완료
# Iteration 260/500
# PolicyNet 학습 및 저장 완료
# Iteration 261/500
# PolicyNet 학습 및 저장 완료
# Iteration 262/500
# PolicyNet 학습 및 저장 완료
# Iteration 263/500
# PolicyNet 학습 및 저장 완료
# Iteration 264/500
# PolicyNet 학습 및 저장 완료
# Iteration 265/500
# PolicyNet 학습 및 저장 완료
# Iteration 266/500
# PolicyNet 학습 및 저장 완료
# Iteration 267/500
# PolicyNet 학습 및 저장 완료
# Iteration 268/500
# PolicyNet 학습 및 저장 완료
# Iteration 269/500
# PolicyNet 학습 및 저장 완료
# Iteration 270/500
# PolicyNet 학습 및 저장 완료
# Iteration 271/500
# PolicyNet 학습 및 저장 완료
# Iteration 272/500
# PolicyNet 학습 및 저장 완료
# Iteration 273/500
# PolicyNet 학습 및 저장 완료
# Iteration 274/500
# PolicyNet 학습 및 저장 완료
# Iteration 275/500
# PolicyNet 학습 및 저장 완료
# Iteration 276/500
# PolicyNet 학습 및 저장 완료
# Iteration 277/500
# PolicyNet 학습 및 저장 완료
# Iteration 278/500
# PolicyNet 학습 및 저장 완료
# Iteration 279/500
# PolicyNet 학습 및 저장 완료
# Iteration 280/500
# PolicyNet 학습 및 저장 완료
# Iteration 281/500
# PolicyNet 학습 및 저장 완료
# Iteration 282/500
# PolicyNet 학습 및 저장 완료
# Iteration 283/500
# PolicyNet 학습 및 저장 완료
# Iteration 284/500
# PolicyNet 학습 및 저장 완료
# Iteration 285/500
# PolicyNet 학습 및 저장 완료
# Iteration 286/500
# PolicyNet 학습 및 저장 완료
# Iteration 287/500
# PolicyNet 학습 및 저장 완료
# Iteration 288/500
# PolicyNet 학습 및 저장 완료
# Iteration 289/500
# PolicyNet 학습 및 저장 완료
# Iteration 290/500
# PolicyNet 학습 및 저장 완료
# Iteration 291/500
# PolicyNet 학습 및 저장 완료
# Iteration 292/500
# PolicyNet 학습 및 저장 완료
# Iteration 293/500
# PolicyNet 학습 및 저장 완료
# Iteration 294/500
# PolicyNet 학습 및 저장 완료
# Iteration 295/500
# PolicyNet 학습 및 저장 완료
# Iteration 296/500
# PolicyNet 학습 및 저장 완료
# Iteration 297/500
# PolicyNet 학습 및 저장 완료
# Iteration 298/500
# PolicyNet 학습 및 저장 완료
# Iteration 299/500
# PolicyNet 학습 및 저장 완료
# Iteration 300/500
# PolicyNet 학습 및 저장 완료
# Iteration 301/500
# PolicyNet 학습 및 저장 완료
# Iteration 302/500
# PolicyNet 학습 및 저장 완료
# Iteration 303/500
# PolicyNet 학습 및 저장 완료
# Iteration 304/500
# PolicyNet 학습 및 저장 완료
# Iteration 305/500
# PolicyNet 학습 및 저장 완료
# Iteration 306/500
# PolicyNet 학습 및 저장 완료
# Iteration 307/500
# PolicyNet 학습 및 저장 완료
# Iteration 308/500
# PolicyNet 학습 및 저장 완료
# Iteration 309/500
# PolicyNet 학습 및 저장 완료
# Iteration 310/500
# PolicyNet 학습 및 저장 완료
# Iteration 311/500
# PolicyNet 학습 및 저장 완료
# Iteration 312/500
# PolicyNet 학습 및 저장 완료
# Iteration 313/500
# PolicyNet 학습 및 저장 완료
# Iteration 314/500
# PolicyNet 학습 및 저장 완료
# Iteration 315/500
# PolicyNet 학습 및 저장 완료
# Iteration 316/500
# PolicyNet 학습 및 저장 완료
# Iteration 317/500
# PolicyNet 학습 및 저장 완료
# Iteration 318/500
# PolicyNet 학습 및 저장 완료
# Iteration 319/500
# PolicyNet 학습 및 저장 완료
# Iteration 320/500
# PolicyNet 학습 및 저장 완료
# Iteration 321/500
# PolicyNet 학습 및 저장 완료
# Iteration 322/500
# PolicyNet 학습 및 저장 완료
# Iteration 323/500
# PolicyNet 학습 및 저장 완료
# Iteration 324/500
# PolicyNet 학습 및 저장 완료
# Iteration 325/500
# PolicyNet 학습 및 저장 완료
# Iteration 326/500
# PolicyNet 학습 및 저장 완료
# Iteration 327/500
# PolicyNet 학습 및 저장 완료
# Iteration 328/500
# PolicyNet 학습 및 저장 완료
# Iteration 329/500
# PolicyNet 학습 및 저장 완료
# Iteration 330/500
# PolicyNet 학습 및 저장 완료
# Iteration 331/500
# PolicyNet 학습 및 저장 완료
# Iteration 332/500
# PolicyNet 학습 및 저장 완료
# Iteration 333/500
# PolicyNet 학습 및 저장 완료
# Iteration 334/500
# PolicyNet 학습 및 저장 완료
# Iteration 335/500
# PolicyNet 학습 및 저장 완료
# Iteration 336/500
# PolicyNet 학습 및 저장 완료
# Iteration 337/500
# PolicyNet 학습 및 저장 완료
# Iteration 338/500
# PolicyNet 학습 및 저장 완료
# Iteration 339/500
# PolicyNet 학습 및 저장 완료
# Iteration 340/500
# PolicyNet 학습 및 저장 완료
# Iteration 341/500
# PolicyNet 학습 및 저장 완료
# Iteration 342/500
# PolicyNet 학습 및 저장 완료
# Iteration 343/500
# PolicyNet 학습 및 저장 완료
# Iteration 344/500
# PolicyNet 학습 및 저장 완료
# Iteration 345/500
# PolicyNet 학습 및 저장 완료
# Iteration 346/500
# PolicyNet 학습 및 저장 완료
# Iteration 347/500
# PolicyNet 학습 및 저장 완료
# Iteration 348/500
# PolicyNet 학습 및 저장 완료
# Iteration 349/500
# PolicyNet 학습 및 저장 완료
# Iteration 350/500
# PolicyNet 학습 및 저장 완료
# Iteration 351/500
# PolicyNet 학습 및 저장 완료
# Iteration 352/500
# PolicyNet 학습 및 저장 완료
# Iteration 353/500
# PolicyNet 학습 및 저장 완료
# Iteration 354/500
# PolicyNet 학습 및 저장 완료
# Iteration 355/500
# PolicyNet 학습 및 저장 완료
# Iteration 356/500
# PolicyNet 학습 및 저장 완료
# Iteration 357/500
# PolicyNet 학습 및 저장 완료
# Iteration 358/500
# PolicyNet 학습 및 저장 완료
# Iteration 359/500
# PolicyNet 학습 및 저장 완료
# Iteration 360/500
# PolicyNet 학습 및 저장 완료
# Iteration 361/500
# PolicyNet 학습 및 저장 완료
# Iteration 362/500
# PolicyNet 학습 및 저장 완료
# Iteration 363/500
# PolicyNet 학습 및 저장 완료
# Iteration 364/500
# PolicyNet 학습 및 저장 완료
# Iteration 365/500
# PolicyNet 학습 및 저장 완료
# Iteration 366/500
# PolicyNet 학습 및 저장 완료
# Iteration 367/500
# PolicyNet 학습 및 저장 완료
# Iteration 368/500
# PolicyNet 학습 및 저장 완료
# Iteration 369/500
# PolicyNet 학습 및 저장 완료
# Iteration 370/500
# PolicyNet 학습 및 저장 완료
# Iteration 371/500
# PolicyNet 학습 및 저장 완료
# Iteration 372/500
# PolicyNet 학습 및 저장 완료
# Iteration 373/500
# PolicyNet 학습 및 저장 완료
# Iteration 374/500
# PolicyNet 학습 및 저장 완료
# Iteration 375/500
# PolicyNet 학습 및 저장 완료
# Iteration 376/500
# PolicyNet 학습 및 저장 완료
# Iteration 377/500
# PolicyNet 학습 및 저장 완료
# Iteration 378/500
# PolicyNet 학습 및 저장 완료
# Iteration 379/500
# PolicyNet 학습 및 저장 완료
# Iteration 380/500
# PolicyNet 학습 및 저장 완료
# Iteration 381/500
# PolicyNet 학습 및 저장 완료
# Iteration 382/500
# PolicyNet 학습 및 저장 완료
# Iteration 383/500
# PolicyNet 학습 및 저장 완료
# Iteration 384/500
# PolicyNet 학습 및 저장 완료
# Iteration 385/500
# PolicyNet 학습 및 저장 완료
# Iteration 386/500
# PolicyNet 학습 및 저장 완료
# Iteration 387/500
# PolicyNet 학습 및 저장 완료
# Iteration 388/500
# PolicyNet 학습 및 저장 완료
# Iteration 389/500
# PolicyNet 학습 및 저장 완료
# Iteration 390/500
# PolicyNet 학습 및 저장 완료
# Iteration 391/500
# PolicyNet 학습 및 저장 완료
# Iteration 392/500
# PolicyNet 학습 및 저장 완료
# Iteration 393/500
# PolicyNet 학습 및 저장 완료
# Iteration 394/500
# PolicyNet 학습 및 저장 완료
# Iteration 395/500
# PolicyNet 학습 및 저장 완료
# Iteration 396/500
# PolicyNet 학습 및 저장 완료
# Iteration 397/500
# PolicyNet 학습 및 저장 완료
# Iteration 398/500
# PolicyNet 학습 및 저장 완료
# Iteration 399/500
# PolicyNet 학습 및 저장 완료
# Iteration 400/500
# PolicyNet 학습 및 저장 완료
# Iteration 401/500
# PolicyNet 학습 및 저장 완료
# Iteration 402/500
# PolicyNet 학습 및 저장 완료
# Iteration 403/500
# PolicyNet 학습 및 저장 완료
# Iteration 404/500
# PolicyNet 학습 및 저장 완료
# Iteration 405/500
# PolicyNet 학습 및 저장 완료
# Iteration 406/500
# PolicyNet 학습 및 저장 완료
# Iteration 407/500
# PolicyNet 학습 및 저장 완료
# Iteration 408/500
# PolicyNet 학습 및 저장 완료
# Iteration 409/500
# PolicyNet 학습 및 저장 완료
# Iteration 410/500
# PolicyNet 학습 및 저장 완료
# Iteration 411/500
# PolicyNet 학습 및 저장 완료
# Iteration 412/500
# PolicyNet 학습 및 저장 완료
# Iteration 413/500
# PolicyNet 학습 및 저장 완료
# Iteration 414/500
# PolicyNet 학습 및 저장 완료
# Iteration 415/500
# PolicyNet 학습 및 저장 완료
# Iteration 416/500
# PolicyNet 학습 및 저장 완료
# Iteration 417/500
# PolicyNet 학습 및 저장 완료
# Iteration 418/500
# PolicyNet 학습 및 저장 완료
# Iteration 419/500
# PolicyNet 학습 및 저장 완료
# Iteration 420/500
# PolicyNet 학습 및 저장 완료
# Iteration 421/500
# PolicyNet 학습 및 저장 완료
# Iteration 422/500
# PolicyNet 학습 및 저장 완료
# Iteration 423/500
# PolicyNet 학습 및 저장 완료
# Iteration 424/500
# PolicyNet 학습 및 저장 완료
# Iteration 425/500
# PolicyNet 학습 및 저장 완료
# Iteration 426/500
# PolicyNet 학습 및 저장 완료
# Iteration 427/500
# PolicyNet 학습 및 저장 완료
# Iteration 428/500
# PolicyNet 학습 및 저장 완료
# Iteration 429/500
# PolicyNet 학습 및 저장 완료
# Iteration 430/500
# PolicyNet 학습 및 저장 완료
# Iteration 431/500
# PolicyNet 학습 및 저장 완료
# Iteration 432/500
# PolicyNet 학습 및 저장 완료
# Iteration 433/500
# PolicyNet 학습 및 저장 완료
# Iteration 434/500
# PolicyNet 학습 및 저장 완료
# Iteration 435/500
# PolicyNet 학습 및 저장 완료
# Iteration 436/500
# PolicyNet 학습 및 저장 완료
# Iteration 437/500
# PolicyNet 학습 및 저장 완료
# Iteration 438/500
# PolicyNet 학습 및 저장 완료
# Iteration 439/500
# PolicyNet 학습 및 저장 완료
# Iteration 440/500
# PolicyNet 학습 및 저장 완료
# Iteration 441/500
# PolicyNet 학습 및 저장 완료
# Iteration 442/500
# PolicyNet 학습 및 저장 완료
# Iteration 443/500
# PolicyNet 학습 및 저장 완료
# Iteration 444/500
# PolicyNet 학습 및 저장 완료
# Iteration 445/500
# PolicyNet 학습 및 저장 완료
# Iteration 446/500
# PolicyNet 학습 및 저장 완료
# Iteration 447/500
# PolicyNet 학습 및 저장 완료
# Iteration 448/500
# PolicyNet 학습 및 저장 완료
# Iteration 449/500
# PolicyNet 학습 및 저장 완료
# Iteration 450/500
# PolicyNet 학습 및 저장 완료
# Iteration 451/500
# PolicyNet 학습 및 저장 완료
# Iteration 452/500
# PolicyNet 학습 및 저장 완료
# Iteration 453/500
# PolicyNet 학습 및 저장 완료
# Iteration 454/500
# PolicyNet 학습 및 저장 완료
# Iteration 455/500
# PolicyNet 학습 및 저장 완료
# Iteration 456/500
# PolicyNet 학습 및 저장 완료
# Iteration 457/500
# PolicyNet 학습 및 저장 완료
# Iteration 458/500
# PolicyNet 학습 및 저장 완료
# Iteration 459/500
# PolicyNet 학습 및 저장 완료
# Iteration 460/500
# PolicyNet 학습 및 저장 완료
# Iteration 461/500
# PolicyNet 학습 및 저장 완료
# Iteration 462/500
# PolicyNet 학습 및 저장 완료
# Iteration 463/500
# PolicyNet 학습 및 저장 완료
# Iteration 464/500
# PolicyNet 학습 및 저장 완료
# Iteration 465/500
# PolicyNet 학습 및 저장 완료
# Iteration 466/500
# PolicyNet 학습 및 저장 완료
# Iteration 467/500
# PolicyNet 학습 및 저장 완료
# Iteration 468/500
# PolicyNet 학습 및 저장 완료
# Iteration 469/500
# PolicyNet 학습 및 저장 완료
# Iteration 470/500
# PolicyNet 학습 및 저장 완료
# Iteration 471/500
# PolicyNet 학습 및 저장 완료
# Iteration 472/500
# PolicyNet 학습 및 저장 완료
# Iteration 473/500
# PolicyNet 학습 및 저장 완료
# Iteration 474/500
# PolicyNet 학습 및 저장 완료
# Iteration 475/500
# PolicyNet 학습 및 저장 완료
# Iteration 476/500
# PolicyNet 학습 및 저장 완료
# Iteration 477/500
# PolicyNet 학습 및 저장 완료
# Iteration 478/500
# PolicyNet 학습 및 저장 완료
# Iteration 479/500
# PolicyNet 학습 및 저장 완료
# Iteration 480/500
# PolicyNet 학습 및 저장 완료
# Iteration 481/500
# PolicyNet 학습 및 저장 완료
# Iteration 482/500
# PolicyNet 학습 및 저장 완료
# Iteration 483/500
# PolicyNet 학습 및 저장 완료
# Iteration 484/500
# PolicyNet 학습 및 저장 완료
# Iteration 485/500
# PolicyNet 학습 및 저장 완료
# Iteration 486/500
# PolicyNet 학습 및 저장 완료
# Iteration 487/500
# PolicyNet 학습 및 저장 완료
# Iteration 488/500
# PolicyNet 학습 및 저장 완료
# Iteration 489/500
# PolicyNet 학습 및 저장 완료
# Iteration 490/500
# PolicyNet 학습 및 저장 완료
# Iteration 491/500
# PolicyNet 학습 및 저장 완료
# Iteration 492/500
# PolicyNet 학습 및 저장 완료
# Iteration 493/500
# PolicyNet 학습 및 저장 완료
# Iteration 494/500
# PolicyNet 학습 및 저장 완료
# Iteration 495/500
# PolicyNet 학습 및 저장 완료
# Iteration 496/500
# PolicyNet 학습 및 저장 완료
# Iteration 497/500
# PolicyNet 학습 및 저장 완료
# Iteration 498/500
# PolicyNet 학습 및 저장 완료
# Iteration 499/500
# PolicyNet 학습 및 저장 완료
# Iteration 500/500
# PolicyNet 학습 및 저장 완료

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
import imageio



def visualize_episode(grid, policy_net, device='cpu', max_episode_len=100):
    frames = []  # Store each frame here to make a video
    episode_info = []  # To store episode information

    policy_net.eval()
    with torch.no_grad():
        for step in range(max_episode_len):
            plt.figure(figsize=(5, 5))
            plt.xticks([])
            plt.yticks([])
            plt.imshow(np.zeros((grid.size, grid.size)), cmap='gray', vmin=0, vmax=1)
            plt.text(grid.exit_pos[0], grid.exit_pos[1], 'Exit', ha='center', va='center', color='green', fontsize=12)
            plt.text(grid.figure_pos[0], grid.figure_pos[1], 'Agent', ha='center', va='center', color='blue', fontsize=12)
            plt.grid(True)
            plt.title(f"Step: {step + 1}")
            plt.savefig('frame.png')
            plt.close()
            frames.append(imageio.imread('frame.png'))

            state = grid.get_state(device)
            action_probs = policy_net(state).squeeze()
            action = np.random.choice(np.arange(4), p=action_probs.detach().cpu().numpy())
            episode_info.append((state.cpu().numpy().tolist(), action))  # Store state and action

            grid.move(action)
            if grid.is_at_exit():
                break

    # Output episode information
    for info in episode_info:
        print(f"State: {info[0]}, Action: {action_probs}")

    # Save the visualized episode
    imageio.mimsave('game_progress.gif', frames, fps=1)
    imageio.mimsave('game_progress.mp4', frames, fps=1)

# 학습된 정책 네트워크 로드
# 정책 네트워크를 학습하고 저장한 후, 여기서 로드해야 합니다.
policy_net = PolicyNet()
policy_net.load_state_dict(torch.load('policy_net.pth'))  # 학습된 모델 파일 로드

# 환경 초기화 및 에피소드 시각화
grid = Grid(size=10, start_pos=(0, 0), exit_pos=(6, 5))
visualize_episode(grid, policy_net)
# Out:
# <ipython-input-6-dcf4691e0581>:27: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   frames.append(imageio.imread('frame.png'))
# State: [[0.0, 0.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[0.0, 0.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[1.0, 0.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[1.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[1.0, 0.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[2.0, 0.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[2.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[2.0, 0.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[2.0, 0.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[2.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[3.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[4.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[5.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[6.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[7.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[8.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 1.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 2.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 2.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 2.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 2.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 2.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 2.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 2.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 2.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 2.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 2.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 2.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 2.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 2.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 2.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 2.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 2.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 2.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 2.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# State: [[9.0, 3.0]], Action: tensor([5.9431e-05, 1.1891e-02, 2.5704e-04, 9.8779e-01])
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (500, 500) to (512, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
